# %% [markdown]
# Defining Functions

# %% [markdown]
#   Write a function called say_hello() that prints 'Welcome to Python!'

# %%
def say_hello():
    print("Welcome to Python")
say_hello()
# Out:
# Welcome to Python

# %% [markdown]
#   Write a function called add(a, b) that returns the sum of two numbers.

# %%
def Add(a,b):
    return a+b
Add(289,909)
# Out:
# 1198

# %% [markdown]
#   What is the output of a function that has no return statement? Write a function to verify
# this.

# %%
def greet():
    print("Hello")
result = greet()
print(result)
# Out:
# Hello
# None

# %% [markdown]
# Write a function area_of_rectangle(length, width) that returns length * width. Call it with
# values 6 and 4.

# %%
def area_of_rectangle(length,width):
    return length*width
area_of_rectangle(6,4)
# Out:
# 24

# %% [markdown]
#   Write a function multiply(a, b, c) that returns the product of three numbers.

# %%
def multiply(a,b,c):
    return a*b*c
multiply(5,6,7)
# Out:
# 210

# %% [markdown]
#   Create a function describe_pet(animal, name) that prints: 'My [animal] is named
# [name].'

# %%
def describe_pet(animal, name):
    print(f"My {animal} is named as {name}")
describe_pet("Dog","kittu")
# Out:
# My Dog is named as kittu

# %% [markdown]
#   What happens if you call a function with fewer arguments than parameters? Try it and
# note the error.

# %%
def fun(name, age, dept):
    print(name,age)
fun("Pooja",22)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 def fun(name, age, dept):
#       2     print(name,age)
# ----> 3 fun("Pooja",22)
#
# TypeError: fun() missing 1 required positional argument: 'dept'

# %% [markdown]
#   Write a function power(base, exponent) that returns base raised to exponent using the
# ** operator.

# %%
def power(base, exponent):
     return base**exponent
power(2,4)
# Out:
# 16

# %% [markdown]
#   Create a function full_name(first, middle, last) that returns the full name as a single
# string.

# %%
def full_name(first, middle,last):
    return first+" "+middle+" "+last
full_name("Pooja","Chow","Meda")
# Out:
# 'Pooja Chow Meda'

# %% [markdown]
# Write a function intro(name, city, hobby) that prints a sentence about a person. Call it
# in two different orders and observe the difference.

# %%
def intro(name, city,hobby):
    print(f"{name} lives in {city} her hobbies is {hobby}")
intro("Pooja","Hyderabad","Travelling")
# Out:
# Pooja lives in Hyderabad her hobbies is Travelling

# %%
def intro(name="Pooja",city="Hyderabad",hobby="travelling"):
    print(f"{name} lives in {city} her hobbies is {hobby}")
intro()
# Out:
# Pooja lives in Hyderabad her hobbies is travelling

# %% [markdown]
# Create subtract(a, b) that returns a - b. What is the difference between subtract(10, 3)
# and subtract(3, 10)  Create subtract(a, b) that returns a - b. What is the difference between subtract(10, 3)
# and subtract(3, 10)?

# %%
def subtract(a,b):
    return a-b
subtract(3,10)
# Out:
# -7

# %% [markdown]
# Write a function bio(first_name, last_name, age) and call it correctly using positional
# arguments.

# %%
def bio(first_name,last_name, age):
    print(f"{first_name}{last_name}")
bio("Pooja"," meda",22)
# Out:
# Pooja meda

# %%
def bio(first_name,last_name, age,dept):
    print(f"{first_name}{last_name}{age}{dept}")
bio("Pooja"," meda ", 22," cse ")
# Out:
# Pooja meda 22 cse

# %% [markdown]
# Q1.  Call the function send_email(to, subject, body) using keyword arguments in any order.

# %%
def send_email(to,subject,body):
    print(f"To:{to}")
    print(f"Subject:{subject}")
    print(f"Body:{body}")
send_email(body="Meeting at tomorrow at 2pm",
           subject="Meeting remainder",
           to="poojameda747@gmail.com")
# Out:
# To:poojameda747@gmail.com
# Subject:Meeting remainder
# Body:Meeting at tomorrow at 2pm

# %%
def create_profile(username, email, age):
    print(f"Username:{username}")
    print(f"Email:{email}")
    print(f"Age:{age}")
create_profile(email="poojameda747@gmail.com",
               age=22,
               username="pooja")
# Out:
# Username:pooja
# Email:poojameda747@gmail.com
# Age:22

# %% [markdown]
# .  Rewrite this call using keyword arguments: book_ticket('Alice', 'Delhi', 'Mumbai', 2)

# %%
def book_ticket(name,source,destination,tickets):
    print(f"Name:{name}")
    print(f"Source:{source}")
    print(f"Destination:{destination}")
    print(f"Tickets:{tickets}")
book_ticket(name="shyamala",source="Delhi",destination="Mumbai",tickets=2)
# Out:
# Name:shyamala
# Source:Delhi
# Destination:Mumbai
# Tickets:2

# %%
def power(base, exponent=2):
    return base**exponent
print(power(2))
print(power(2,7))
# Out:
# 4
# 128

# %%
def connect(host,port=3306,protocol="TCP"):
    print(f"Host:{host}")
    print(f"Port:{port}")
    print(f"Protocol:{protocol}")
connect("localhost",8809)
# Out:
# Host:localhost
# Port:8809
# Protocol:TCP

# %%
def discount_price(price,discount=10):
    print(f"Price:{price}")
    print(f"Discount:{discount}")
discount_price(899)
# Out:
# Price:899
# Discount:10

# %%
def fun(*args):
    print(a)
    print(*a)
fun(10,20,30,40,60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       1 def fun(*args):
#       2     print(a)
#       3     print(*a)
# ----> 4 fun(10,20,30,40,60)
#
# Cell In[34], line 2, in fun(*args)
#       1 def fun(*args):
# ----> 2     print(a)
#       3     print(*a)
#
# NameError: name 'a' is not defined
